# %%
from matplotlib import pyplot


def show(image_ndarray):
    pyplot.imshow(image_ndarray)

# %%
from skimage import io, color, transform

imagem = color.rgb2gray(io.imread('imagem.jpg'))
imagem = transform.resize(imagem, map(lambda i: int(i*0.1), imagem.shape))
show(imagem)
print(imagem.shape)
# Out:
# (412, 232)

# %%
from skimage import io, color

janela = color.rgb2gray(io.imread('janela.jpg'))
janela = transform.resize(janela, map(lambda i: int(i*0.1), janela.shape))
show(janela)
print(janela.shape)
# Out:
# (219, 80)

# %%
from scipy import ndimage
import numpy

result = ndimage.convolve(imagem, janela, output)
show(result)
