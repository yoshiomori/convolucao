# %%
from matplotlib import pyplot


def show(image_ndarray):
    pyplot.imshow(image_ndarray)

# %%
from skimage import io, color

imagem = color.rgb2gray(io.imread('imagem.jpg'))
show(imagem)
print(imagem.shape)
# Out:
# (4128, 2322)

# %%
from skimage import io, color

janela = color.rgb2gray(io.imread('janela.jpg'))
show(janela)
print(janela.shape)
# Out:
# (2194, 801)

# %%
from scipy import ndimage
import numpy

output = numpy.zeros(imagem.shape[0] * imagem.shape[1]).reshape(imagem.shape)
ndimage.convolve(imagem, janela, output)
show(result)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-8b872178a6cd> in <module>
#       3
#       4 output = numpy.zeros(imagem.shape[0] * imagem.shape[1]).reshape(imagem.shape)
# ----> 5 ndimage.convolve(imagem, janela, output)
#       6 show(result)
#
# ~\anaconda3\lib\site-packages\scipy\ndimage\filters.py in convolve(input, weights, output, mode, cval, origin)
#     799
#     800     """
# --> 801     return _correlate_or_convolve(input, weights, output, mode, cval,
#     802                                   origin, True)
#     803
#
# ~\anaconda3\lib\site-packages\scipy\ndimage\filters.py in _correlate_or_convolve(input, weights, output, mode, cval, origin, convolution)
#     627         raise RuntimeError("A sequence of modes is not supported")
#     628     mode = _ni_support._extend_mode_to_code(mode)
# ...
